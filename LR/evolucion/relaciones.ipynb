# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

datossim = '/home/meugenia/al_final/LR/evolucion/datos/'
datosobs = '/home/meugenia/al_final/LR/tablas/'
publicados = '/home/meugenia/al_final/LR/evolucion/publicados/'
paths = '/home/meugenia/al_final/LR/evolucion/relaciones/'
flavsim = '_LR_minpot3_rmmax_BiasedProgenitor_Masses.txt'
flavobs = 'LR_minpot3_rmmax_'
flavcsf = 'LR_CSF_'

file0sim = '091'+flavsim
file1sim = '041'+flavsim
file2sim = '032'+flavsim
file3sim = '026'+flavsim

file0obs = flavobs+'091_band125_nodust_grupo0.txt'
file1obs = flavobs+'041_band125_nodust_grupo0.txt'
file2obs = flavobs+'032_band125_nodust_grupo0.txt'
file3obs = flavobs+'026_band125_nodust_grupo0.txt'

file0csf = flavcsf+'091_band125_nodust_grupo0.txt'

r500, m500, r200, m200                    = np.loadtxt(datossim+file0sim,usecols=[2,3,4,5] , unpack=True)
m30,  m50 , m70 , m10                     = np.loadtxt(datossim+file0sim,usecols=[6,7,8,9] , unpack=True)
m30p, m50p, m70p                          = np.loadtxt(datossim+file0sim,usecols=[10,11,12], unpack=True)
m500_z1, m200_z1, m10_z1, m30_z1, m50_z1  = np.loadtxt(datossim+file1sim,usecols=[3,5,9,10,11] , unpack=True)
m500_z2, m200_z2, m10_z2, m30_z2, m50_z2  = np.loadtxt(datossim+file2sim,usecols=[3,5,9,10,11] , unpack=True)
m500_z3, m200_z3, m10_z3, m30_z3, m50_z3  = np.loadtxt(datossim+file3sim,usecols=[3,5,9,10,11] , unpack=True)
m091                                      = np.loadtxt(datosobs+file0obs,usecols=[2], unpack=True)
m041                                      = np.loadtxt(datosobs+file1obs,usecols=[2], unpack=True)
m032                                      = np.loadtxt(datosobs+file2obs,usecols=[2], unpack=True)
m026                                      = np.loadtxt(datosobs+file3obs,usecols=[2], unpack=True)
#m091_mu25                          = np.loadtxt(path+'LR_minpot3_rmmax/nodust/mu25/091_nodust_band125.txt',usecols=[3], unpack=True)
m091_csf                                  = np.loadtxt(datosobs+file0csf,usecols=[2], unpack=True)
m091_agn=[m091[0],m091[1]]
m200_csf=[1.267e15,4.079e14]
m200_sub=[m200[0],m200[1]]

# %%
bahe='bahe_2017_hydrangea_fromFig4.txt'
gonz='gonzalez_krav_total.txt'
krav='kravtsovBCGs_2014.txt'
pill='pillepich_2017_illustrisTNG_fromFig9.txt'
gon2='gonzalezBCGs_2013_fromFig17Kravt2014.txt'
zang='zhang.txt'
bell='bellstedt+2016.dat'

# %%
m200_bahe, mbcg_bahe                                 = np.loadtxt(publicados+bahe,usecols=[0,1]    , unpack=True, skiprows=1)
m500_gonz, mbcg_gonz                                 = np.loadtxt(publicados+gonz,usecols=[0,1]    , unpack=True, skiprows=1) 
m500_krav, mbcg_krav, m10_krav, m30_krav, m50_krav   = np.loadtxt(publicados+krav,usecols=[1,4,5,6,7]  , unpack=True, skiprows=3)
m500_pill, mbcg_pill                                 = np.loadtxt(publicados+pill,usecols=[0,1]    , unpack=True, skiprows=1) #30_3D
m500_gon2, mbcg_gon2                                 = np.loadtxt(publicados+gon2,usecols=[0,1]    , unpack=True, skiprows=1) #50_2D
m200_zang,z,mbcg_zang                                = np.loadtxt(publicados+zang,usecols=[0,1,2]  , unpack=True, skiprows=1) #32_2D
zb,mbcg_bell,m200_bell                               = np.loadtxt(publicados+bell,usecols=[0,3,4]  , unpack=True, skiprows=4) #32_2D

# %%
mbcg_zang1=mbcg_zang[z<0.2]
m200_zang1=m200_zang[z<0.2]
mbcg_bell1=mbcg_bell[z<0.2]
m200_bell1=m200_bell[z<0.2]
mbcg_zang2=mbcg_zang[z>0.7]
m200_zang2=m200_zang[z>0.7]
mbcg_bell2=mbcg_bell[zb>0.7]
m200_bell2=m200_bell[zb>0.7]
#mbcg_zang1=mbcg_zang[m200_zang1 > 14]
#m200_zang1=m200_zang[m200_zang1 > 14]

# %%
_r=[0,1,2,3]
_nn=np.log10(1.5*1e14)
_lm0=[11.52,11.6]
_a=[0.24,0.30]
_b=[-0.16,-0.24]
_lm200=np.linspace(13,15.5,1000)

def ajuste(r,nn,lm0,a,b,lm200):
    ajuste = lm0+a*lm200-a*nn+b*np.log10(1+r)
    return ajuste

# %%
m200_krav = 1.5*m500_krav*1e14
m200_gonz = 1.5*m500_gonz
m200_gon2 = 1.5*m500_gon2
m200_pill = 1.5*m500_pill
mbcg_krav = mbcg_krav*1e12
m10_krav  = m10_krav*1e11
m30_krav  = m30_krav*1e11
m50_krav  = m50_krav*1e11
m200_bahe = 10**(m200_bahe)
mbcg_bahe = 10**(mbcg_bahe)
m200_zang = 10**(m200_zang)
mbcg_zang = 10**(mbcg_zang)
m200_zang1 = 10**(m200_zang1)
mbcg_zang1 = 10**(mbcg_zang1)
m200_zang2 = 10**(m200_zang2)
mbcg_zang2 = 10**(mbcg_zang2)
mbcg_bell1  = mbcg_bell1*1e12
m200_bell1  = m200_bell1*1e15
mbcg_bell2  = mbcg_bell2*1e12
m200_bell2  = m200_bell2*1e15

# %%
from matplotlib.offsetbox import AnchoredText

plt.rc('text', usetex=True)
font = {'family': 'serif', 'size': 35, 'serif': ['computer modern roman']}
plt.rc('font', **font)
plt.rc('legend', **{'fontsize': 24}) #27 
plt.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}']

plt.rcParams['axes.linewidth'] = 1.0
plt.rcParams['xtick.major.size'] = 8
plt.rcParams['xtick.minor.size'] = 4
plt.rcParams['ytick.major.size'] = 6
plt.rcParams['ytick.minor.size'] = 3
mpl.rc('lines', linewidth=3)

# %%
#Masas Totales
#frame1 = plt.gca()
#plt.axis('scaled')
#fig = plt.figure(figsize=(7,7))

#ax1 = fig.add_subplot(111)
#plt.scatter(np.log10(m200),np.log10(m091_mu25), marker='v',s=300, edgecolor='black',hatch='$////$',facecolor='#FF8000',label='M$_{\mu_{25}}$', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    
#plt.scatter(np.log10(m200),np.log10(m091), marker='v',s=300, color='#FF8000',label='M$_{\mu_{24}}$', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    
#plt.scatter(np.log10(m200_krav),np.log10(mbcg_krav), marker='o',s=100, color='#A0A0A0',label='Kravtsov+ 14', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    
#plt.scatter(np.log10(m200_gonz),np.log10(mbcg_gonz), marker='s',s=100, color='#5A5A5A',label='Gonzalez+ 13', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    

#ax1.set_xlim(13.8,15.8)
#ax1.set_ylim(11.3,13.2)
#xticks1 = ax1.xaxis.get_major_ticks()
#xticks1[0].label1.set_visible(False)
#xticks1[-1].label1.set_visible(False)
#x1.set_ylabel('log $M_{\star}$/$M_{\odot}$')
#ax1.set_xlabel('log $M_{200}$/$M_{\odot}$')
    
#ax1.legend(loc='upper left', frameon=False, scatterpoints=1,borderpad=0.3, labelspacing=0.2,handletextpad=0.1)
#ax1.minorticks_on()
#plt.savefig(paths+'Mbcg_vs_M200.pdf', format='pdf', dpi=1500,bbox_inches='tight')
#plt.show()

# %%
#Masas varias a distintos redshifts
from matplotlib.ticker import NullFormatter,MultipleLocator, FormatStrFormatter

fig = plt.figure(figsize=(15,15))

ax1 = fig.add_subplot(221)
ax1.scatter(np.log10(m200),np.log10(m10), marker='^',s=500, color='#009999',label='M$_{R\le0.1R_{500}}$', alpha=0.7) 
ax1.scatter(np.log10(m200),np.log10(m091), marker='v',s=500, color='#FF8000',label='M$_{\mu_{24}}$', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen'   
ax1.scatter(np.log10(m200_krav),np.log10(m10_krav), marker='o',s=170, color='#A0A0A0',label='Kravtsov+ 14', alpha=0.8)    
 
#ax1.scatter(np.log10(m200_gonz),np.log10(mbcg_gonz), marker='s',s=400, color='#5A5A5A',label='Gonzalez+ 13', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    

ax1.set_xlim(12.5,15.8)
ax1.set_ylim(10.4,13)
xticks1 = ax1.xaxis.get_major_ticks()
xticks1[0].label1.set_visible(False)
xticks1[-1].label1.set_visible(False)
yticks1 = ax1.yaxis.get_major_ticks()
yticks1[0].label1.set_visible(False)
yticks1[-1].label1.set_visible(False)
ax1.xaxis.set_major_formatter(NullFormatter())
ax1.set_ylabel('log $M_{\star}$/$M_{\odot}$')
ax1.legend(loc='upper left', frameon=False, scatterpoints=1,borderpad=0.3, labelspacing=0.2,handletextpad=0.1)
ax1.minorticks_on()

#--------------------------------------------------------------------------------------------------------
ax2 = fig.add_subplot(222)  
  
ax2.scatter(np.log10(m200_z1),np.log10(m10_z1), marker='^',s=500, color='#009999',label='M$_{R\le0.1R_{500}}$', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    
ax2.scatter(np.log10(m200_z1),np.log10(m041), marker='v',s=500, color='#FF8000',label='M$_{\mu_{24}}$', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    

ax2.set_xlim(12.5,15.8)
ax2.set_ylim(10.4,13)
xticks1 = ax1.xaxis.get_major_ticks()
xticks1[0].label1.set_visible(False)
xticks1[-1].label1.set_visible(False)
ax2.xaxis.set_major_formatter(NullFormatter())
ax2.yaxis.set_major_formatter(NullFormatter())
ax2.legend(loc='upper left', frameon=False, scatterpoints=1,borderpad=0.3, labelspacing=0.2,handletextpad=0.1)
ax2.minorticks_on()

#--------------------------------------------------------------------------------------------------------
ax3 = fig.add_subplot(223)
ax3.scatter(np.log10(m200_z2),np.log10(m10_z2), marker='^',s=500, color='#009999',label='M$_{R\le0.1R_{500}}$', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    
ax3.scatter(np.log10(m200_z2),np.log10(m032), marker='v',s=500, color='#FF8000',label='M$_{\mu_{24}}$', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    
  
ax3.set_xlim(12.5,15.8)
ax3.set_ylim(10.4,13)
xticks3 = ax3.xaxis.get_major_ticks()
xticks3[0].label1.set_visible(False)
xticks3[-1].label1.set_visible(False)
yticks3 = ax3.yaxis.get_major_ticks()
yticks3[0].label1.set_visible(False)
yticks3[-1].label1.set_visible(False)
xticks3[-2].label1.set_visible(False)
xticks3[1].label1.set_visible(False)
ax3.set_ylabel('log $M_{\star}$/$M_{\odot}$')
ax3.set_xlabel('log $M_{200}$/$M_{\odot}$')
ax3.legend(loc='upper left', frameon=False, scatterpoints=1,borderpad=0.3, labelspacing=0.2,handletextpad=0.1)
ax3.minorticks_on()


#--------------------------------------------------------------------------------------------------------
ax4 = fig.add_subplot(224)
ax4.scatter(np.log10(m200_z3),np.log10(m10_z3), marker='^',s=500, color='#009999',label='M$_{R\le0.1R_{500}}$', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    
ax4.scatter(np.log10(m200_z3),np.log10(m026), marker='v',s=500, color='#FF8000',label='M$_{\mu_{24}}$', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )      

ax4.set_xlim(12.5,15.8)
ax4.set_ylim(10.4,13)
xticks4 = ax4.xaxis.get_major_ticks()
xticks4[0].label1.set_visible(False)
xticks4[-1].label1.set_visible(False)
xticks4[-2].label1.set_visible(False)
xticks4[1].label1.set_visible(False)
ax4.yaxis.set_major_formatter(NullFormatter())
ax4.set_xlabel('log $M_{200}$/$M_{\odot}$')
ax4.legend(loc='upper left', frameon=False, scatterpoints=1,borderpad=0.3, labelspacing=0.2,handletextpad=0.1)
ax4.minorticks_on()

text0='z=0'
text1='z=1'
text2='z=2'
text3='z=3'

ax1.annotate(text0, xy=(1, 1), xytext=(-60, -400), fontsize=30,
                 xycoords='axes fraction', textcoords='offset points',
                 horizontalalignment='left', verticalalignment='bottom')         

ax2.annotate(text1, xy=(1, 1), xytext=(-60, -400), fontsize=30,
                 xycoords='axes fraction', textcoords='offset points',
                 horizontalalignment='left', verticalalignment='bottom')     

ax3.annotate(text2, xy=(1, 1), xytext=(-60, -400), fontsize=30,
                 xycoords='axes fraction', textcoords='offset points',
                 horizontalalignment='left', verticalalignment='bottom')     

ax4.annotate(text3, xy=(1, 1), xytext=(-60, -400), fontsize=30,
                 xycoords='axes fraction', textcoords='offset points',
                 horizontalalignment='left', verticalalignment='bottom')     





plt.subplots_adjust(wspace=0, hspace=0)

plt.savefig(paths+'muvs10r.pdf', format='pdf', dpi=1500,bbox_inches='tight')
plt.show()

# %%
#Masas Apertura 50 Kpc 2D
fig = plt.figure(figsize=(7,7))

ax1 = fig.add_subplot(111)
plt.scatter(np.log10(m200),np.log10(m50p), marker='^',s=300, color='#009999',label='M$_{R\le50Kpc}$', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    
plt.scatter(np.log10(m200_krav),np.log10(m50_krav) , marker='o',s=100, color='#A0A0A0',label='Kravtsov+ 14', alpha=0.8)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    
plt.scatter(np.log10(m200_bahe),np.log10(mbcg_bahe), marker='*',s=100, color='#A0A0A0',label='Bahe+ 17 -- C-EAGLE', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    
plt.scatter(np.log10(m200_gon2),np.log10(mbcg_gon2), marker='s',s=100, color='#5A5A5A',label='Gonzalez+ 13', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    

redshift=0.
logmpiv=np.log10(1.5*1e14)
logm0=11.60
alfa=0.30
beta=-0.24
logm200=np.linspace(14,15.5,1000)
ajuste50=logm0+alfa*logm200-alfa*logmpiv+beta*np.log10(1+redshift)

plt.plot(logm200,ajuste50,color="#282828",linestyle='--',linewidth=1.,label='Zhang+ 16')

ax1.set_xlim(13.7,15.8)
ax1.set_ylim(11.4,13.)
xticks1 = ax1.xaxis.get_major_ticks()
xticks1[0].label1.set_visible(False)
xticks1[-1].label1.set_visible(False)

ax1.set_ylabel('log $M_{\star}$/$M_{\odot}$')
ax1.set_xlabel('log $M_{200}$/$M_{\odot}$')

ax1.legend(loc='upper left', frameon=False, scatterpoints=1,borderpad=0.3, labelspacing=0.2,handletextpad=0.1)
ax1.minorticks_on()
plt.savefig(paths+'M502D_vs_M200.pdf', format='pdf', dpi=1500,bbox_inches='tight')
plt.show()

# %%
# Masas Aperturas 30 Kpc 2D
fig = plt.figure(figsize=(7,7))
si=np.array([])

redshift=0.
logmpiv=np.log10(1.5*1e14)
logm0=11.52
alfa=0.24
beta=-0.19
logm200=np.linspace(14,15.5,1000)


ajuste30=logm0+alfa*logm200-alfa*logmpiv+beta*np.log10(1+redshift)


ax1 = fig.add_subplot(111)
#si = [110/(3*n) for n in z]    
plt.scatter(np.log10(m200_pill),np.log10(mbcg_pill), marker='.',s=90, color='#5A5A5A',label='Pillepich+ 17 -- IllustrisTNG', alpha=0.4)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    
plt.scatter(np.log10(m200_zang1),np.log10(mbcg_zang1), marker='H',s=90, color='#464543',label='Zhang+ 16', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    
plt.scatter(np.log10(m200_krav),np.log10(m30_krav) , marker='o',s=90, color='#A0A0A0',label='Kravtsov+ 14', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    
plt.scatter(np.log10(m200),np.log10(m30p), marker='^',s=300, color='#009999',label='M$_{R\le30Kpc}$', alpha=0.7)#plt.scatter(np.log10(m500_krav),np.log10(mbcg_krav), marker='o',s=90, color='#00D0A6',label='Kravtsov')#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    
plt.plot(logm200,ajuste30,color="#282828",linestyle='--',linewidth=1.,label='Zhang+ 16')

ax1.set_xlim(13.6,15.8)
ax1.set_ylim(10.7,13.2)
xticks1 = ax1.xaxis.get_major_ticks()
xticks1[0].label1.set_visible(False)
xticks1[-1].label1.set_visible(False)
ax1.set_ylabel('log $M_{\star}$/$M_{\odot}$')
ax1.set_xlabel('log $M_{200}$/$M_{\odot}$')
            
ax1.legend(loc='upper left', frameon=False, scatterpoints=1,borderpad=0.3, labelspacing=0.2,handletextpad=0.1)
ax1.minorticks_on()
plt.savefig(paths+'M302D_vs_M200.pdf', format='pdf', dpi=1500,bbox_inches='tight')
plt.show()

# %%
#Masas varias a distintos redshifts vs zhanggggg
from matplotlib.ticker import NullFormatter,MultipleLocator, FormatStrFormatter

fig = plt.figure(figsize=(20,20))

#ax1 = fig.add_subplot(221)
#ax1.scatter(np.log10(m200),np.log10(m10), marker='^',s=500, color='#009999',label='M$_{R\le0.1R_{500}}$', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    
#ax1.scatter(np.log10(m200),np.log10(m091), marker='v',s=500, color='#FF8000',label='M$_{\mu_{24}}$', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    
#ax1.scatter(np.log10(m200_krav),np.log10(m10_krav), marker='o',s=170, color='#A0A0A0',label='Kravtsov+ 14', alpha=0.8)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    
 
#ax1.scatter(np.log10(m200_gonz),np.log10(mbcg_gonz), marker='s',s=400, color='#5A5A5A',label='Gonzalez+ 13', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    

trucho1  = plt.Rectangle((0,0), 0,0, color='white', alpha=0.3)
trucho2  = plt.Rectangle((0,0), 0,0, color='white', alpha=0.3)



ax1 = fig.add_subplot(221)  

p12=ax1.plot(_lm200,ajuste(_r[0],_nn,_lm0[1],_a[1],_b[1],_lm200), color='#464543',linestyle='-',linewidth=1.,label='Zhang+ 16 -- 50 Kpc')
p11=ax1.plot(_lm200,ajuste(_r[0],_nn,_lm0[0],_a[0],_b[0],_lm200), color='#464543',linestyle='--',linewidth=1.,label='Zhang+ 16 -- 32 Kpc')
p13=ax1.scatter(np.log10(m200),np.log10(m50p), marker='^',s=500, color='#009999',label='log M$_{R\le50 Kpc}$', alpha=0.7)
p14=ax1.scatter(np.log10(m200),np.log10(m30p), marker='v',s=500, label='log M$_{R\le30 Kpc}$', facecolor='#009999',edgecolor='black',linewidth=0.5,hatch='$////$',alpha=0.7)
p15=plt.scatter(np.log10(m200_zang1),np.log10(mbcg_zang1), marker='H',s=170, color='#464543',label='Zhang+ 16', alpha=0.7)
p16=plt.scatter(np.log10(m200_bell1),np.log10(mbcg_bell1), marker='o',s=170, color='#A0A0A0',label='Bellstedt+ 16', alpha=0.7)

objects = [p13, p14, p15, p16, p12[0],p11[0],trucho1,trucho2]
labels = ['log M$_{R\le50 Kpc}$','log M$_{R\le30 Kpc}$','Zhang+ 16 ; z$<$0.2','Bellstedt+ 16 ; z$<$0.2','Zhang+ 16 -- 50 Kpc','Zhang+ 16 -- 32 Kpc','','']

ax1.set_xlim(12.5,15.8)
ax1.set_ylim(10.8,12.7)
xticks1 = ax1.xaxis.get_major_ticks()
xticks1[0].label1.set_visible(False)
xticks1[-1].label1.set_visible(False)
yticks1 = ax1.yaxis.get_major_ticks()
yticks1[0].label1.set_visible(False)
yticks1[-1].label1.set_visible(False)
ax1.xaxis.set_major_formatter(NullFormatter())
ax1.set_ylabel('log $M_{\star}$/$M_{\odot}$')
ax1.legend(objects,labels,loc='upper left', frameon=False, scatterpoints=1,borderpad=0.3, labelspacing=0.2,handletextpad=0.1,ncol=2,columnspacing=0.)
ax1.minorticks_on()

#--------------------------------------------------------------------------------------------------------
ax2 = fig.add_subplot(222)  
  
#ax2.scatter(np.log10(m200_z1),np.log10(m10_z1), marker='^',s=500, color='#009999',label='M$_{R\le0.1R_{500}}$', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    
#ax2.scatter(np.log10(m200_z1),np.log10(m041), marker='v',s=500, color='#FF8000',label='M$_{\mu_{24}}$', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    


ax2.plot(_lm200,ajuste(_r[1],_nn,_lm0[0],_a[0],_b[0],_lm200), color='#464543',linestyle='--',linewidth=1.)
ax2.plot(_lm200,ajuste(_r[1],_nn,_lm0[1],_a[1],_b[1],_lm200), color='#464543',linestyle='-',linewidth=1.)
ax2.scatter(np.log10(m200_z1),np.log10(m50_z1), marker='^',s=500, color='#009999',label='log M$_{R\le50 Kpc}$', alpha=0.7)
ax2.scatter(np.log10(m200_z1),np.log10(m30_z1), marker='v',s=500,label='log M$_{R\le30 Kpc}$',facecolor='#009999',edgecolor='black',linewidth=0.5,hatch='$////$',alpha=0.7)
plt.scatter(np.log10(m200_zang2),np.log10(mbcg_zang2), marker='H',s=170, color='#464543',label='Zhang+ 16 ; z$>$0.7', alpha=0.7)
plt.scatter(np.log10(m200_bell2),np.log10(mbcg_bell2), marker='o',s=170, color='#A0A0A0',label='Bellstedt+ 16 ; z$>$0.7', alpha=0.7)


ax2.set_xlim(12.5,15.8)
ax2.set_ylim(10.8,12.7)
xticks1 = ax1.xaxis.get_major_ticks()
xticks1[0].label1.set_visible(False)
xticks1[-1].label1.set_visible(False)
ax2.xaxis.set_major_formatter(NullFormatter())
ax2.yaxis.set_major_formatter(NullFormatter())
ax2.legend(loc='upper left', frameon=False, scatterpoints=1,borderpad=0.3, labelspacing=0.2,handletextpad=0.1)
ax2.minorticks_on()

#--------------------------------------------------------------------------------------------------------
ax3 = fig.add_subplot(223)
#ax3.scatter(np.log10(m200_z2),np.log10(m10_z2), marker='^',s=500, color='#009999',label='M$_{R\le0.1R_{500}}$', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    
#ax3.scatter(np.log10(m200_z2),np.log10(m032), marker='v',s=500, color='#FF8000',label='M$_{\mu_{24}}$', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    
 
    
ax3.plot(_lm200,ajuste(_r[2],_nn,_lm0[0],_a[0],_b[0],_lm200), color='#464543',linestyle='--',linewidth=1.)
ax3.plot(_lm200,ajuste(_r[2],_nn,_lm0[1],_a[1],_b[1],_lm200), color='#464543',linestyle='-',linewidth=1.)
ax3.scatter(np.log10(m200_z2),np.log10(m50_z2), marker='^',s=500, color='#009999',label='log M$_{R\le50 Kpc}$', alpha=0.7)
ax3.scatter(np.log10(m200_z2),np.log10(m30_z2), marker='v',s=500,label='log M$_{R\le30 Kpc}$', facecolor='#009999',edgecolor='black',linewidth=0.5,hatch='$////$',alpha=0.7)    
    
ax3.set_xlim(12.5,15.8)
ax3.set_ylim(10.8,12.7)
xticks3 = ax3.xaxis.get_major_ticks()
xticks3[0].label1.set_visible(False)
xticks3[-1].label1.set_visible(False)
yticks3 = ax3.yaxis.get_major_ticks()
yticks3[0].label1.set_visible(False)
yticks3[-1].label1.set_visible(False)
#xticks3[-2].label1.set_visible(False)

ax3.set_ylabel('log $M_{\star}$/$M_{\odot}$')
ax3.set_xlabel('log $M_{200}$/$M_{\odot}$')
ax3.legend(loc='upper left', frameon=False, scatterpoints=1,borderpad=0.3, labelspacing=0.2,handletextpad=0.1)
ax3.minorticks_on()


#--------------------------------------------------------------------------------------------------------
ax4 = fig.add_subplot(224)
#ax4.scatter(np.log10(m200_z3),np.log10(m10_z3), marker='^',s=500, color='#009999',label='M$_{R\le0.1R_{500}}$', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    
#ax4.scatter(np.log10(m200_z3),np.log10(m026), marker='v',s=500, color='#FF8000',label='M$_{\mu_{24}}$', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )      #

ax4.plot(_lm200,ajuste(_r[3],_nn,_lm0[0],_a[0],_b[0],_lm200), color='#464543',linestyle='--',linewidth=1.)
ax4 .plot(_lm200,ajuste(_r[3],_nn,_lm0[1],_a[1],_b[1],_lm200), color='#464543',linestyle='-',linewidth=1.)
ax4.scatter(np.log10(m200_z3),np.log10(m50_z3), marker='^',s=500, color='#009999',label='log M$_{R\le50 Kpc}$', alpha=0.7)
ax4.scatter(np.log10(m200_z3),np.log10(m30_z3), marker='v',s=500, label='log M$_{R\le30 Kpc}$', facecolor='#009999',edgecolor='black',linewidth=0.5,hatch='$////$',alpha=0.7)


ax4.set_xlim(12.5,15.8)
ax4.set_ylim(10.8,12.7)
xticks4 = ax4.xaxis.get_major_ticks()
xticks4[0].label1.set_visible(False)
xticks4[-1].label1.set_visible(False)
#xticks4[-2].label1.set_visible(False)

ax4.yaxis.set_major_formatter(NullFormatter())
ax4.set_xlabel('log $M_{200}$/$M_{\odot}$')
ax4.legend(loc='upper left', frameon=False, scatterpoints=1,borderpad=0.3, labelspacing=0.2,handletextpad=0.1)
ax4.minorticks_on()

text0='z=0'
text1='z=1'
text2='z=2'
text3='z=3'

ax1.annotate(text0, xy=(1, 1), xytext=(-60, -550), fontsize=30,
                 xycoords='axes fraction', textcoords='offset points',
                 horizontalalignment='left', verticalalignment='bottom')         

ax2.annotate(text1, xy=(1, 1), xytext=(-60, -550), fontsize=30,
                 xycoords='axes fraction', textcoords='offset points',
                 horizontalalignment='left', verticalalignment='bottom')     

ax3.annotate(text2, xy=(1, 1), xytext=(-60, -550), fontsize=30,
                 xycoords='axes fraction', textcoords='offset points',
                 horizontalalignment='left', verticalalignment='bottom')     

ax4.annotate(text3, xy=(1, 1), xytext=(-60, -550), fontsize=30,
                 xycoords='axes fraction', textcoords='offset points',
                 horizontalalignment='left', verticalalignment='bottom')     



plt.subplots_adjust(wspace=0, hspace=0)

plt.savefig(paths+'zhang_vs_z.pdf', format='pdf', dpi=1500,bbox_inches='tight')
plt.show()

# %%
#csf vs agn
fig = plt.figure(figsize=(7,7))

ax1 = fig.add_subplot(111)
plt.scatter(np.log10(m200_csf),np.log10(m091_csf), marker='v',s=1000, edgecolor='black',hatch='$////$',facecolor='#FF8000',label='M$_{\mu_{24}}$ -- AGN OFF', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )    
plt.scatter(np.log10(m200_sub),np.log10(m091_agn), marker='v',s=1000, color='#FF8000',label='M$_{\mu_{24}}$ -- AGN ON', alpha=0.7)#,hatch='$////////////////$',edgecolor='forestgreen',linewidth='1', alpha=0.8, label='M(R$<$0.1R$_{500}$)' )       

ax1.set_xlim(14.5,15.5)
ax1.set_ylim(11.7,13.7)
xticks1 = ax1.xaxis.get_major_ticks()
xticks1[0].label1.set_visible(False)
xticks1[-1].label1.set_visible(False)
ax1.set_ylabel('log $M_{\star}$/$M_{\odot}$')
ax1.set_xlabel('log $M_{200}$/$M_{\odot}$')
    
ax1.legend(loc='upper left', frameon=False, scatterpoints=1,borderpad=0.3, labelspacing=0.2,handletextpad=0.1)
ax1.minorticks_on()
plt.savefig(paths+'csf_agn.pdf', format='pdf', dpi=1500,bbox_inches='tight')
plt.show()

# %%
# Out:
# array([  1.20390000e+13,   5.45370000e+12])

# %%
m091_agn
# Out:
# [127.34999999999999, 85.920000000000002]
