# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt 
from scipy.optimize import curve_fit
import scipy.optimize as optimize
from matplotlib.ticker import NullFormatter,MultipleLocator, FormatStrFormatter
from matplotlib.offsetbox import AnchoredText
import os

# %%
def sersic_charly_ie(r,ie,re,beta):
    return ie*np.exp(-(2./beta-0.33)*((r/re)**beta-1))

# %%
def sersic_charly_mue(r,mue,re,beta):
    return mue + 2.5*(2./beta-0.33)*((r/re)**beta -1)/np.log(10)

# %%
def mu(_ie):
    return -2.5*np.log10(_ie)-48.6 -0.044

# %%
pathd='/home/meugenia/al_final/LR/'
flav ='LR_minpot3_rmmax'
files = '/home/meugenia/al_final/plots/bineado_perfiles/'
paths=pathd+'plots/perfiles/'
patht=pathd+'tablas/'
pathreg= pathd+flav+'/nodust/grupo0/mu24/'
prefie='ie_medios125_D'
prefmu='mu_medios125_D'

# %%
m091,rmu24_091      = np.loadtxt(patht+flav+'_091_band125_nodust_grupo0.txt',usecols=[2,3], unpack=True)
m041,rmu24_041      = np.loadtxt(patht+flav+'_041_band125_nodust_grupo0.txt',usecols=[2,3], unpack=True)

# %%
#defino los vectores de distancia radial y brillo superficial de cada región, para cada redshift.
limite_oficial = 38
n_tot_regiones = 30
banda = '125'

r_041_reg   = np.zeros((n_tot_regiones,limite_oficial))
r_091_reg   = np.zeros((n_tot_regiones,limite_oficial))
i_041_reg  = np.zeros((n_tot_regiones,limite_oficial))
i_091_reg  = np.zeros((n_tot_regiones,limite_oficial))
m_041_reg  = np.zeros((n_tot_regiones,limite_oficial))
m_091_reg  = np.zeros((n_tot_regiones,limite_oficial))

for j in range(n_tot_regiones):
    if j==0:
        continue
    with open(files+prefie+str(j)+'_'+'041.txt') as f:
        lineas041 = len(f.readlines())
    limite041 = lineas041 - limite_oficial 
    r_041_reg[j] = np.genfromtxt(files+prefie+str(j)+'_'+'041.txt', usecols=[0] , unpack=True,skip_footer= limite041)
    i_041_reg[j] = np.genfromtxt(files+prefie+str(j)+'_'+'041.txt', usecols=[1] , unpack=True,skip_footer= limite041)
    m_041_reg[j] = np.genfromtxt(files+prefmu+str(j)+'_'+'041.txt', usecols=[1] , unpack=True,skip_footer= limite041)

for j in range(n_tot_regiones):
    if j==0:
        continue
    with open(files+prefie+str(j)+'_'+'091.txt') as f:
        lineas091 = len(f.readlines())
    limite091 = lineas091 - limite_oficial 
    r_091_reg[j] = np.genfromtxt(files+prefie+str(j)+'_'+'091.txt', usecols=[0] , unpack=True,skip_footer= limite091)
    i_091_reg[j] = np.genfromtxt(files+prefie+str(j)+'_'+'091.txt', usecols=[1] , unpack=True,skip_footer= limite091)
    m_091_reg[j] = np.genfromtxt(files+prefmu+str(j)+'_'+'091.txt', usecols=[1] , unpack=True,skip_footer= limite091)

# %%
m_041_reg[j]
# Out:
# array([ 18.79,  20.68,  21.12,  21.35,  21.83,  22.13,  22.37,  22.72,
#         23.21,  23.1 ,  23.41,  23.56,  23.54,  23.76,  23.89,  23.96,
#         24.05,  24.09,  24.14,  24.41,  24.77,  25.  ,  25.14,  25.19,
#         25.39,  25.39,  24.98,  24.66,  24.82,  25.51,  25.83,  25.84,
#         25.89,  26.45,  26.58,  26.88,  26.85,  27.28])

# %%
from matplotlib.offsetbox import AnchoredText

plt.rc('text', usetex=True)
font = {'family': 'serif', 'size': 29, 'serif': ['computer modern roman']}
plt.rc('font', **font)
plt.rc('legend', **{'fontsize': 15}) 
plt.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}']

plt.rcParams['axes.linewidth'] = 1.0
plt.rcParams['xtick.major.size'] = 8
plt.rcParams['xtick.minor.size'] = 4
plt.rcParams['ytick.major.size'] = 6
plt.rcParams['ytick.minor.size'] = 3
mpl.rc('lines', linewidth=3)

# %%
#Hago ajustes 1componente de Sersic. Comentar Linea que guarda resultados en caso de no querer modificar los ya obtenidos 
#Los ajuste estan hechos dentro de Rmu24

#Z=0

if os.path.exists('__ajustes_z0_ie.txt'):
    os.remove('__ajustes_z0_ie.txt')
    
ajustes = open('__ajustes_z0_ie.txt','a')
for i in range(30):
    if i == 0:#or i == 6 or i == 9 or i == 28:# or i == 16 or i == 20 or i == 28 or i == 29:
        continue
    elif i==28 :
        index = next(x[0] for x in enumerate(r_091_reg[i]) if x[1] > rmu24_091[i-1])
        xdata = r_091_reg[i][1:index+3]
        ydata = i_091_reg[i][1:index+3]
        p=[5e-18,40,0.25]
        popt, pcov = curve_fit(sersic_charly_ie, xdata, ydata,p)       
    else:    
        index =  next(x[0] for x in enumerate(r_091_reg[i]) if x[1] > rmu24_091[i-1])
        xdata = r_091_reg[i][1:index+1]
        ydata = i_091_reg[i][1:index+1]
        p=[5e-18,40,0.25]
        popt, pcov = curve_fit(sersic_charly_ie, xdata, ydata,p)    
    ajustes.write('{ie:9.3g} {re:9.3g} {n:9.3g} {errmue:9.3g} {errre:9.3g} {errn:9.3g}\n'.format(ie=popt[0], re=popt[1], n=popt[2],
    errmue=pcov[0][0], errre=pcov[1][1], errn=pcov[2][2]))
    #print i
    print i, popt[0], popt[1], popt[2]
    
    #print i,'   ',rmu24_041[i-1],'   ', xdata[-2],'   ',xdata[-1],'   ',mu(ydata[-2]/4.2545e10),'   ',mu(ydata[-1]/4.2545e10)    
ajustes.close()
# Out:
# 1 2.68455922602e-20 660.616379374 0.140240818188
# 2 2.35671030308e-18 36.0965841333 1.63643766242
# 3 1.22410867246e-18 52.434661786 0.877215358742
# 4 4.59842669556e-19 63.6139446492 0.563358851556
# 5 6.98245382946e-19 35.3258469889 1.0939173535
# 6 1.52237347491e-18 69.0650749953 1.48486424809
# 7 1.87881377902e-18 57.1962986358 1.03506523212
# 8 6.04131897623e-19 67.7326185708 0.486065064168
# 9 2.03988547441e-19 68.5336127787 0.64531134524
# 10 1.16535267407e-18 75.4094882825 0.959715469687
# 11 8.10519639091e-19 83.732985929 0.609107583316
# 12 2.12689609077e-19 176.600093778 0.39554460623
# 13 4.72885898106e-22 20088.1133805 0.145041655389
# 14 1.92770362651e-18 56.1721563187 0.930750917443
# 15 9.39502001819e-19 76.5936120809 0.527998182305
# 16 8.26590385839e-19 86.9063021224 0.528827441897
# 17 1.60141788881e-21 3301.67953745 0.126782962389
# 18
#  1.10342738949e-20 1759.36389088 0.196688032917
# 19 3.44684810226e-19 131.395645778 0.408285758489
# 20 1.56433598142e-18 66.482367798 0.697044812389
# 21 2.06195185388e-18 50.5416270114 0.72260796862
# 22 9.30857555627e-19 85.5462843254 0.665526909715
# 23 1.4949210535e-19 186.868729168 0.330525841964
# 24 1.95608956894e-18 54.6237130108 0.763245089998
# 25 8.52785301936e-20 158.112431345 0.256128666504
# 26 1.22853663624e-18 63.4380606514 0.757731848236
# 27 8.11978837487e-20 347.364822721 0.3070411839
# 28 2.79581995291e-21 5182.8361398 0.171099986941
# 29 1.03946904279e-19 262.815789874 0.389850027289

# %%
#Hago ajustes 1componente de Sersic. Comentar Linea que guarda resultados en caso de no querer modificar los ya obtenidos 
#Los ajustes estan hechos dentro de Rmu24

#Z=1
if os.path.exists('__ajustes_z1_ie.txt'):
    os.remove('__ajustes_z1_ie.txt')
    
ajustes = open('__ajustes_z1_ie.txt','a')
for i in range(30):
    if i == 0 :#or i == 9:# or i == 16 or i == 25:# or i == 13 or i == 16 or i == 20 or i == 28 or i == 29:
        continue
    elif i==18 :
        index = next(x[0] for x in enumerate(r_041_reg[i]) if x[1] > rmu24_041[i-1])
        xdata = r_041_reg[i][3:index+1]
        ydata = i_041_reg[i][3:index+1]
        p=[9e-18,70,0.773]
        #p=[1e-18,60,0.40]
        popt, pcov = curve_fit(sersic_charly_ie, xdata, ydata,p)        
    else:    
        index = next(x[0] for x in enumerate(r_041_reg[i]) if x[1] > rmu24_041[i-1])
        xdata = r_041_reg[i][1:index+1]
        ydata = i_041_reg[i][1:index+1]
        p=[1e-18,60,0.40]
        popt, pcov = curve_fit(sersic_charly_ie, xdata, ydata,p)    
    ajustes.write('{ie:9.3g} {re:9.3g} {n:9.3g} {errmue:9.3g} {errre:9.3g} {errn:9.3g}\n'.format(ie=popt[0], re=popt[1], n=popt[2],
    errmue=pcov[0][0], errre=pcov[1][1], errn=pcov[2][2]))
    print i, popt[0], popt[1], popt[2]
    #print i,'   ',rmu24_041[i-1],'   ', xdata[-2],'   ',xdata[-1],'   ',mu(ydata[-2]/4.2545e10),'   ',mu(ydata[-1]/4.2545e10)    
    
ajustes.close()
# Out:
# 1 2.3646340065e-18 29.6538976463 1.18979719106
# 2 3.05458791486e-18 29.4699012078 0.817504506749
# 3 2.88776512323e-18 34.9743598821 1.31111714343
# 4 3.04243816445e-18 25.4369814559 2.85557354473
# 5 1.75371590669e-18 28.6304217581 1.25043945381
# 6 1.90462040472e-18 52.8556842728 0.980207231941
# 7 1.64972903047e-18 48.3438876592 0.754074097225
# 8 7.1339144548e-20 213.107294832 0.0959341351904
# 9 9.55568795075e-20 155.929745832 0.280222126771
# 10 2.58821896942e-19 172.906544756 0.356429604533
# 11 2.28959329418e-18 29.7306048985 1.80147153559
# 12 2.82035255903e-18 38.2574691292 0.982747710698
# 13 2.45172985445e-18 32.2019095916 0.888222211388
# 14 7.75960758726e-19 109.61387841 0.284969612432
# 15 2.0675130274e-18 46.6951045983 0.529749711045
# 16 5.37764128681e-20 651.340251073 0.192851399834
# 17 5.90318877783e-19 81.0643450303 0.186426610267
# 18 5.61580804582e-20 404.846810082 0.184353110658
# 19 1.37632533231e-20 2727.79583328 0.298422757326
# 20 2.57124375698e-18 45.5821495376 0.472878152963
# 21 2.44421736115e-18 54.9527638847 0.601071735295
# 22 2.60972188141e-19 190.942073711 0.265731701097
# 23 7.25376353696e-19 55.9157163481 0.387095308666
# 24 1.04482152755e-18 82.5321800006 0.413715042485
# 25 2.31101250983e-18 41.8839988924 1.44440451742
# 26 2.23429189196e-18 47.5340205312 0.623715198612
# 27 1.01864630197e-18 61.3376770596 0.367458330384
# 28 2.75487959272e-18 42.5436647405 0.75847969935
# 29 1.41411381982e-18 60.4374929187 0.636862444387

# %%
ie,re,beta    = np.loadtxt('__ajustes_z0_ie.txt',usecols=[0,1,2] ,unpack=True)#, skiprows=1)
ie1,re1,beta1 = np.loadtxt('__ajustes_z1_ie.txt',usecols=[0,1,2] ,unpack=True)

# %%
r_fit=np.linspace(0,150,100)
mu_e = mu(ie[0])
y_mue = sersic_charly_mue(r_fit, mu_e,re[0],beta[0])
y_ie  = sersic_charly_ie(r_fit, ie[0] ,re[0],beta[0])

# %%
fig = plt.figure(figsize=(50,50))
i=1
r_fit=np.linspace(0,150,100)
for ii in range(6):
    for jj in range(5):
        if i==30:
            continue
        ax=plt.subplot2grid((6,5), (ii,jj))
        y_ie  = sersic_charly_ie(r_fit, ie[i-1] ,re[i-1],beta[i-1])
        y_ie1  = sersic_charly_ie(r_fit, ie1[i-1] ,re1[i-1],beta1[i-1])
        ax.plot( r_091_reg[i][1:70], i_091_reg[i][1:70], label='ie-datos-z0',
                color='orange',marker='o',ms=10,linestyle='--',mec='orange', mew=2, mfc='gray',alpha=0.5)
        ax.plot(r_fit,y_ie, label='ie-charly-z0', color='orange')
        ax.plot( r_041_reg[i][1:70], i_041_reg[i][1:70], label='ie-datos-z1',
                color='purple',marker='o',ms=10,linestyle='--' ,mec='purple', mew=2, mfc='gray',alpha=0.5)
        ax.plot(r_fit,y_ie1, label='ie-charly-z1', color='purple')
        ax.legend(loc='upper right', frameon=False, scatterpoints=1,borderpad=0.1, labelspacing=0)
        ax.set_ylim(-0.1e-17,1.6e-17)
        ax.set_xlim(0,130)
        ax.set_title('D'+str(i))
        xticks = ax.xaxis.get_major_ticks()
        xticks[0].label1.set_visible(False)
        xticks[-1].label1.set_visible(False)
        yticks = ax.yaxis.get_major_ticks()
        yticks[0].label1.set_visible(False)
        yticks[-1].label1.set_visible(False)
        #p1.title('D'+str(i))
        i=i+1
        
#plt.savefig('ajustes.pdf', format='pdf', dpi=1500,bbox_inches='tight') 
plt.show()

# %%
fig = plt.figure(figsize=(50,50))
i=1
for ii in range(6):
    for jj in range(5):
        if i==30:
            continue
        ax=plt.subplot2grid((6,5), (ii,jj))
        mu_e = mu(ie[i-1]/4.2545e10)
        y_mue = sersic_charly_mue(r_fit, mu_e,re[i-1],beta[i-1])       
        ax.scatter( r_091_reg[i][1:70], mu(i_091_reg[i][1:70]/4.2545e10), label='mue-datos',color='orange',marker='.',s=100)
        ax.plot(r_fit,y_mue, label='mue-charly', color='purple')
        ax.legend(loc='upper right', frameon=False, scatterpoints=1,borderpad=0.1, labelspacing=0)
        ax.set_ylim(27,18)
        ax.set_xlim(0,130)
        ax.set_title('D'+str(i))
        xticks = ax.xaxis.get_major_ticks()
        xticks[0].label1.set_visible(False)
        xticks[2].label1.set_visible(False)
        xticks[4].label1.set_visible(False)
        xticks[6].label1.set_visible(False)
        xticks[-1].label1.set_visible(False)
        yticks = ax.yaxis.get_major_ticks()
        yticks[0].label1.set_visible(False)
        yticks[2].label1.set_visible(False)
        yticks[4].label1.set_visible(False)
        yticks[6].label1.set_visible(False)
        yticks[-1].label1.set_visible(False)
        #p1.title('D'+str(i))
        i=i+1
        
#plt.savefig('ajustes_mu.pdf', format='pdf', dpi=1500,bbox_inches='tight') 
plt.show()

# %%
for i in range(30):
    mu_e = mu(ie[i-1]/4.2545e10)
    y_mue = sersic_charly_mue(r_fit, mu_e,re[i-1],beta[i-1])
    print mu_e
# Out:
# 25.3855379717
# 26.8577843349
# 21.9958413126
# 22.7122217433
# 23.7712267408
# 23.3184827634
# 22.4735123501
# 22.2427266968
# 23.4755289734
# 24.6540459014
# 22.7576566656
# 23.1555691845
# 24.6071723114
# 31.2409684681
# 22.2142280475
# 22.995301686
# 23.1343575461
# 29.9178213633
# 27.8246396071
# 24.0835735823
# 22.4453098241
# 22.1434532691
# 23.0057471175
# 24.995155649
# 22.1974811416
# 25.6007487421
# 22.7033585414
# 25.6542312469
# 29.3102262416
# 25.3855379717

# %%
#ajuste en mu

#Z=0
if os.path.exists('__ajustes_z0_mu.txt'):
    os.remove('__ajustes_z0_mu.txt')

ajustes = open('__ajustes_z0_mu.txt','a')
for i in range(30):
    if i==0:
        continue
    elif i==29:
        index = next(x[0] for x in enumerate(r_091_reg[i]) if x[1] > rmu24_091[i-1])
        xdata = r_091_reg[i][3:index+10]
        ydata = m_091_reg[i][3:index+10]
        p=[22,40,0.7]
        popt, pcov = curve_fit(sersic_charly_mue, xdata, ydata,p)        
    else:    
        index = next(x[0] for x in enumerate(r_091_reg[i]) if x[1] > rmu24_091[i-1])
        xdata = r_091_reg[i][1:index+1]
        ydata = m_091_reg[i][1:index+1]
        p=[22.3,55,0.3]
        popt, pcov = curve_fit(sersic_charly_mue, xdata, ydata,p)
    print i, popt[0], popt[1], popt[2]
    #print i,'   ',rmu24_041[i-1],'   ', xdata[-2],'   ',xdata[-1],'   ',ydata[-2],'   ',ydata[-1]
    ajustes.write('{mue:10.5g} {re:10.5g} {beta:10.5g} {errmue:10.5g} {errre:10.5g} {errbeta:10.5g}\n'.format(mue=popt[0], re=popt[1], beta=popt[2],
         errmue=pcov[0][0], errre=pcov[1][1], errbeta=pcov[2][2]))

ajustes.close()
# Out:
# 1 24.7398850007 191.343786161 0.231074673638
# 2 22.8713297622 51.3557942729 0.712700573091
# 3 22.9176046111 55.3244238062 0.783798010805
# 4 23.9507494914 66.6475458504 0.53119076276
# 5 23.6613707369 40.3892724895 0.856541543206
# 6 23.0219864632 85.8552001459 0.970147785234
# 7 23.2424512095 91.722137382 0.549709717504
# 8 24.3831618188 108.039593111 0.342937134518
# 9 24.3932609711 54.5721897566 0.7853684676
# 10 23.2080619811 90.8779312235 0.740920502868
# 11 24.4178135396 162.044559748 0.354388468536
# 12 23.888947784 107.986678466 0.554371231096
# 13 30.2824651603 9581.87065556 0.164128477082
# 14 23.0618008843 80.7767624622 0.521900813578
# 15 23.2095129771 80.8980055632 0.480607597735
# 16 23.9315331649 130.507159842 0.390686555653
# 17 24.9086734657 145.616536486 0.35566231332
# 18 23.5528663543 108.024374332 0.709142327888
# 19 23.9165314681 111.738220134 0.447862174789
# 20 22.3221220777 60.1824189952 0.831068564005
# 21 23.9194917599 120.243770774 0.278977434537
# 22 24.3267280333 170.876303571 0.368787423485
# 23 26.5115764161 447.220145863 0.227206023899
# 24 23.3403022361 91.9743948927 0.381478341261
# 25 27.1483425435 368.58413082 0.179174778712
# 26 23.2580690698 81.1540621135 0.558131653121
# 27 29.2224408619 3190.96443032 0.157596520871
# 28 23.5588513247 107.714242067 0.826984147297
# 29 24.6178921058 158.939189716 0.603872898012

# %%
#ajuste en mu

#Z=1
if os.path.exists('__ajustes_z1_mu.txt'):
    os.remove('__ajustes_z1_mu.txt')
ajustes = open('__ajustes_z1_mu.txt','a')
for i in range(30):
    if i==0:
        continue 
    elif i==18:
        index = next(x[0] for x in enumerate(r_041_reg[i]) if x[1] > rmu24_041[i-1])
        xdata = r_041_reg[i][1:index+4]
        ydata = m_041_reg[i][1:index+4]
        p=[23,90,0.7]
        popt, pcov = curve_fit(sersic_charly_mue, xdata, ydata,p)        
    else:    
        index = next(x[0] for x in enumerate(r_041_reg[i]) if x[1] > rmu24_041[i-1])
        xdata = r_041_reg[i][1:index+1]
        ydata = m_041_reg[i][1:index+1]
        p=[24,40,0.25]
        popt, pcov = curve_fit(sersic_charly_mue, xdata, ydata,p)
    print i, popt[0], popt[1], popt[2]
    #print i,'   ',rmu24_041[i-1],'   ', xdata[-2],'   ',xdata[-1],'   ',ydata[-2],'   ',ydata[-1]
    ajustes.write('{mue:10.5g} {re:10.5g} {beta:10.5g} {errmue:10.5g} {errre:10.5g} {errbeta:10.5g}\n'.format(mue=popt[0], re=popt[1], beta=popt[2],
         errmue=pcov[0][0], errre=pcov[1][1], errbeta=pcov[2][2]))

ajustes.close()
# Out:
# 1 22.3930618279 33.2995770588 0.748247194902
# 2 23.7175480084 72.0391660174 0.184829082815
# 3 22.1723069318 39.3659173936 0.877145901036
# 4 22.1402922939 28.2541296603 1.45226169055
# 5 22.6962416479 32.3588635961 0.859631416969
# 6 23.5785157407 97.3935134488 0.401669939082
# 7 23.3228948475 72.3656310428 0.400175361662
# 8 26.5895868506 300.78481297 0.0796629531733
# 9 23.9906038637 63.0643643523 0.541932202223
# 10 22.92736402 70.7908641828 0.764798920371
# 11 22.5995948871 35.9293722175 0.912504815677
# 12 22.873596744 60.3198983397 0.418183815158
# 13 23.0196206532 49.3140133372 0.336143196004
# 14 22.3117122066 67.8537135366 0.516440942896
# 15 22.3075268992 48.7602113077 0.510188218476
# 16 22.7092215119 85.8148847682 0.618998604337
# 17 24.541439312 133.042471379 0.141175526628
# 18 35.7653431267 69002.5426004 0.0455057169438
# 19 24.6954681179 246.97211687 0.679447859833
# 20 23.4357759345 93.8721089463 0.215838843658
# 21 22.1793938854 57.7572911056 0.533611641826
# 22 23.1304335481 89.9607896635 0.452395756933
# 23 24.0472355226 79.3903075839 0.272421993501
# 24 22.8646490319 77.3210147431 0.425979639669
# 25 22.2803353365 44.3087139311 1.16054930719
# 26 22.7508752119 64.1276935077 0.409374934448
# 27 22.6992390609 53.4938177232 0.465464363525
# 28 22.5524908597 56.7568359872 0.436168519164
# 29 24.115776001 129.154143785 0.28744592952

# %%
mue,ree,betaa = np.loadtxt('__ajustes_z0_mu.txt',usecols=[0,1,2] ,unpack=True)
mue1,ree1,betaa1 = np.loadtxt('__ajustes_z1_mu.txt',usecols=[0,1,2] ,unpack=True)

# %%
#todos los perfiles de intensidad especifica
fig = plt.figure(figsize=(70,140))
i=1
r_fit=np.linspace(0,200,200)
for ii in range(8):
    for jj in range(4):
        if i==30:
            continue
        ax=plt.subplot2grid((8,4), (ii,jj))
        
        ie_mu  = 4.2545e10*10**(-(mue[i-1]  + 48.6+0.044)/2.5)
        ie_mu1 = 4.2545e10*10**(-(mue1[i-1] + 48.6+0.044)/2.5)

        y_sersic_mu  = sersic_charly_ie(r_fit,ie_mu,ree[i-1],betaa[i-1])
        y_sersic_mu1 = sersic_charly_ie(r_fit,ie_mu1,ree1[i-1],betaa1[i-1])

        y_ie = sersic_charly_ie(r_fit, ie[i-1] ,re[i-1],beta[i-1]) 
        y_ie1 = sersic_charly_ie(r_fit, ie1[i-1] ,re1[i-1],beta1[i-1])
        
        ax.plot( r_091_reg[i][1:70],i_091_reg[i][1:70],color='#FF8000',
                   label='ie-data-z0',mfc='gray', mec='#FF8000', mew=3.2, marker='o',ms=10,alpha=0.7,linewidth='4')
        ax.plot(r_fit,y_sersic_mu, label='mu-fit-z0', color='#CC6600',linestyle='-.')
        ax.plot(r_fit,y_ie, label='ie-fit-z0', color='#994C00', linestyle='--')

        ax.plot( r_041_reg[i][1:70],i_041_reg[i][1:70],color='#CC0066',
                   label='ie-data-z1',mfc='gray', mec='#CC0066', mew=3.2, marker='o',ms=10,alpha=0.7,linewidth='4')
        ax.plot(r_fit,y_sersic_mu1, label='mu-fit-z1', color='#99004C',linestyle='-.')
        ax.plot(r_fit,y_ie1, label='ie-fit-z1', color='#660033', linestyle='--')         

        pc  = plt.Rectangle((0,0), 0,0, color='white', alpha=0.3, label='dummy-tophead')
        l1  = plt.Line2D((0,1),(0,0), color='k', linestyle='-.')
        l2  = plt.Line2D((0,1),(0,0), color='k', linestyle='--')

    
        n=1./beta[i-1]
        nn=1./betaa[i-1]
        n1=1./beta1[i-1]
        nn1=1./betaa1[i-1]
    
        #ax.legend([p7,p1,p2,p3,p7,p4,p5,p6],labels, ncol=2) # Two columns, vertical group labels    
        w1="$I_{e}:$ "+"${0:0.2e}$".format(ie_mu)
        w2='$r_{e}: $ '+str(round(ree[i-1],2))
        w3='$n: $ '+str(round(nn,2))
        w4="$I_{e}:$ "+"${0:0.2e}$".format(ie[i-1])
        w5='$r_{e}: $ '+str(round(re[i-1],2))
        w6='$n: $ '+str(round(n,2))
        w7="$I_{e}:$ "+"${0:0.2e}$".format(ie_mu1)
        w8='$r_{e}: $ '+str(round(ree1[i-1],2))
        w9='$n: $ '+str(round(nn1,2))
        w10="$I_{e}:$ "+"${0:0.2e}$".format(ie1[i-1])
        w11='$r_{e}: $ '+str(round(re1[i-1],2))
        w12='$n: $ '+str(round(n1,2))
        w13='$R_{\mu_{24}}: $ '+str(round(rmu24_091[i-1],2))
        w14='$R_{\mu_{24}}: $ '+str(round(rmu24_041[i-1],2))
    
  
        objects=[pc,pc,pc,l1,pc,pc,pc,l2,pc,pc,pc,
             pc,pc,pc,pc,pc,pc,pc,pc,pc,pc,pc,
             pc,pc,pc,pc,pc,pc,pc,pc,pc,pc,pc]    
    
    
        labels= ['','','','$\mu$-fit','','','','$I_{e}$-fit','','','',
             'z=0','',w1,w2,w3,'',w4,w5,w6,'',w13,
             'z=1','',w7,w8,w9,'',w10,w11,w12,'',w14]
        
        l=plt.legend(objects, labels , loc='upper right', frameon=False,ncol=3,scatterpoints=1,borderpad=0.2, 
               labelspacing=0,columnspacing=-1,handlelength=2,handletextpad=0,borderaxespad=0.2)

        l.get_texts()[11].set_color('#994C00')
        l.get_texts()[13].set_color('#994C00')
        l.get_texts()[14].set_color('#994C00')
        l.get_texts()[15].set_color('#994C00')
        l.get_texts()[17].set_color('#994C00')
        l.get_texts()[18].set_color('#994C00')
        l.get_texts()[19].set_color('#994C00')    
        l.get_texts()[21].set_color('#994C00')
    
        l.get_texts()[22].set_color('#660033')
        l.get_texts()[24].set_color('#660033')
        l.get_texts()[25].set_color('#660033')
        l.get_texts()[26].set_color('#660033')
        l.get_texts()[28].set_color('#660033')
        l.get_texts()[29].set_color('#660033')
        l.get_texts()[30].set_color('#660033')
        l.get_texts()[32].set_color('#660033')

        ax.set_ylabel("I$_{e}$ [$erg s^{-1} cm^{-2} Hz^{-1} sr^{-1} $]")
        ax.set_xlabel('R [Kpc]')      
        
        ax.set_ylim(-0.1e-17,1e-17)
        ax.set_xlim(0,130)
        ax.set_title('D'+str(i))
        xticks = ax.xaxis.get_major_ticks()
        xticks[0].label1.set_visible(False)
        xticks[-1].label1.set_visible(False)
        yticks = ax.yaxis.get_major_ticks()
        yticks[0].label1.set_visible(False)
        #yticks[6].label1.set_visible(False)
        yticks[-1].label1.set_visible(False)
        ax.minorticks_on()
        #p1.title('D'+str(i))
        i=i+1
        
plt.savefig('/home/meugenia/Plantillas/ajustes_ies.pdf', format='pdf', dpi=1500,bbox_inches='tight') 
plt.show()

# %%
#perfiles de ie para cada region, una imagen por separado
r_fit=np.linspace(0,150,100)
for i in range(30):
    if i==30 or i==0:
        continue
    fig = plt.figure(figsize=(7,7))
    ax = fig.add_subplot(111) 
    
    ie_mu  = 4.2545e10*10**(-(mue[i-1]  + 48.6+0.044)/2.5)
    ie_mu1 = 4.2545e10*10**(-(mue1[i-1] + 48.6+0.044)/2.5)

    y_sersic_mu  = sersic_charly_ie(r_fit,ie_mu,ree[i-1],betaa[i-1])
    y_sersic_mu1 = sersic_charly_ie(r_fit,ie_mu1,ree1[i-1],betaa1[i-1])

    y_ie = sersic_charly_ie(r_fit, ie[i-1] ,re[i-1],beta[i-1]) 
    y_ie1 = sersic_charly_ie(r_fit, ie1[i-1] ,re1[i-1],beta1[i-1])
    
    ax.plot( r_091_reg[i][1:70],i_091_reg[i][1:70],color='#FF8000',
        label='ie-data-z0',mfc='gray', mec='#FF8000', mew=3.2, marker='o',ms=10,alpha=0.7,linewidth='4')
    ax.plot(r_fit,y_sersic_mu, label='mu-fit-z0', color='#CC6600',linestyle='-.')
    ax.plot(r_fit,y_ie, label='ie-fit-z0', color='#994C00', linestyle='--')
    ax.plot( r_041_reg[i][1:70],i_041_reg[i][1:70],color='#CC0066',
        label='ie-data-z1',mfc='gray', mec='#CC0066', mew=3.2, marker='o',ms=10,alpha=0.7,linewidth='4')
    ax.plot(r_fit,y_sersic_mu1, label='mu-fit-z1', color='#99004C',linestyle='-.')
    ax.plot(r_fit,y_ie1, label='ie-fit-z1', color='#660033', linestyle='--')         

    pc  = plt.Rectangle((0,0), 0,0, color='white', alpha=0.3, label='dummy-tophead')
    l1  = plt.Line2D((0,1),(0,0), color='k', linestyle='-.')
    l2  = plt.Line2D((0,1),(0,0), color='k', linestyle='--')

    
    n=1./beta[0]
    nn=1./betaa[0]
    n1=1./beta1[0]
    nn1=1./betaa1[0]
    
    #ax.legend([p7,p1,p2,p3,p7,p4,p5,p6],labels, ncol=2) # Two columns, vertical group labels    
    w1="$I_{e}:$ "+"${0:0.2e}$".format(ie_mu)
    w2='$r_{e}: $ '+str(round(ree[i-1],2))
    w3='$n: $ '+str(round(nn,2))
    w4="$I_{e}:$ "+"${0:0.2e}$".format(ie[i-1])
    w5='$r_{e}: $ '+str(round(re[i-1],2))
    w6='$n: $ '+str(round(n,2))
    w7="$I_{e}:$ "+"${0:0.2e}$".format(ie_mu1)
    w8='$r_{e}: $ '+str(round(ree1[i-1],2))
    w9='$n: $ '+str(round(nn1,2))
    w10="$I_{e}:$ "+"${0:0.2e}$".format(ie1[i-1])
    w11='$r_{e}: $ '+str(round(re1[i-1],2))
    w12='$n: $ '+str(round(n1,2))
    w13='$R_{\mu_{24}}: $ '+str(round(rmu24_091[i-1],2))
    w14='$R_{\mu_{24}}: $ '+str(round(rmu24_041[i-1],2))
    
    objects=[pc,pc,pc,l1,pc,pc,pc,l2,pc,pc,pc,
             pc,pc,pc,pc,pc,pc,pc,pc,pc,pc,pc,
             pc,pc,pc,pc,pc,pc,pc,pc,pc,pc,pc]    
    
    
    labels= ['','','','$\mu$-fit','','','','$I_{e}$-fit','','','',
             'z=0','',w1,w2,w3,'',w4,w5,w6,'',w13,
             'z=1','',w7,w8,w9,'',w10,w11,w12,'',w14]
    l=plt.legend(objects, labels , loc='upper right', frameon=False,ncol=3,scatterpoints=1,borderpad=0.2, 
               labelspacing=0,columnspacing=-1,handlelength=2,handletextpad=0,borderaxespad=0.2)

    l.get_texts()[11].set_color('#994C00')
    l.get_texts()[13].set_color('#994C00')
    l.get_texts()[14].set_color('#994C00')
    l.get_texts()[15].set_color('#994C00')
    l.get_texts()[17].set_color('#994C00')
    l.get_texts()[18].set_color('#994C00')
    l.get_texts()[19].set_color('#994C00')    
    l.get_texts()[21].set_color('#994C00')
    
    l.get_texts()[22].set_color('#660033')
    l.get_texts()[24].set_color('#660033')
    l.get_texts()[25].set_color('#660033')
    l.get_texts()[26].set_color('#660033')
    l.get_texts()[28].set_color('#660033')
    l.get_texts()[29].set_color('#660033')
    l.get_texts()[30].set_color('#660033')
    l.get_texts()[32].set_color('#660033')
    
    ax.set_ylabel("I$_{e}$ [$erg s^{-1} cm^{-2} Hz^{-1} sr^{-1} $]")
    ax.set_xlabel('R [Kpc]')
    
    ax.set_ylim(-0.10e-17,1e-17)
    ax.set_xlim(0,130)
    ax.set_title('D'+str(i))
    xticks = ax.xaxis.get_major_ticks()
    xticks[0].label1.set_visible(False)
    xticks[-1].label1.set_visible(False)
    yticks = ax.yaxis.get_major_ticks()
    yticks[0].label1.set_visible(False)
    #yticks[6].label1.set_visible(False)
    yticks[-1].label1.set_visible(False)
    ax.minorticks_on()
    #p1.title('D'+str(i))
    plt.savefig('plots2/ajustes_ies_D'+str(i)+'.pdf', format='pdf', dpi=1500,bbox_inches='tight') 
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-313-6456cc7a5afa> in <module>()
#      95     ax.minorticks_on()
#      96     #p1.title('D'+str(i))
# ---> 97     plt.savefig('plots2/ajustes_ies_D'+str(i)+'.pdf', format='pdf', dpi=1500,bbox_inches='tight')
#      98     plt.show()
#
# /usr/lib64/python2.7/site-packages/matplotlib/pyplot.pyc in savefig(*args, **kwargs)
#     575 def savefig(*args, **kwargs):
#     576     fig = gcf()
# --> 577     res = fig.savefig(*args, **kwargs)
#     578     draw()   # need this if 'transparent=True' to reset colors
#     579     return res
#
# /usr/lib64/python2.7/site-packages/matplotlib/figure.pyc in savefig(self, *args, **kwargs)
#    1474             self.set_frameon(frameon)
#    1475
# -> 1476         self.canvas.print_figure(*args, **kwargs)
#    1477
#    1478         if frameon:
#
# /usr/lib64/python2.7/site-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2209                 orientation=orientation,
#    2210                 bbox_inches_restore=_bbox_inches_restore,
# -> 2211                 **kwargs)
#    2212         finally:
#    2213             if bbox_inches and restore_bbox:
#
# /usr/lib64/python2.7/site-packages/matplotlib/backends/backend_pdf.pyc in print_pdf(self, filename, **kwargs)
#    2475             file = filename._file
#    2476         else:
# -> 2477             file = PdfFile(filename)
#    2478         try:
#    2479             file.newPage(width, height)
#
# /usr/lib64/python2.7/site-packages/matplotlib/backends/backend_pdf.pyc in __init__(self, filename)
#     416         self.tell_base = 0
#     417         if is_string_like(filename):
# --> 418             fh = open(filename, 'wb')
#     419         elif is_writable_file_like(filename):
#     420             try:
#
# IOError: [Errno 2] No such file or directory: 'plots2/ajustes_ies_D1.pdf'

# %%
#todos los perfiles para mu
fig = plt.figure(figsize=(70,140))
i=1
r_fit=np.linspace(0,200,200)
for ii in range(8):
    for jj in range(4):
        if i==30:
            continue
        ax=plt.subplot2grid((8,4), (ii,jj))
        
        y_mue = sersic_charly_mue(r_fit,mue[i-1] ,ree[i-1],betaa[i-1])
        y_ie_mu = mu(sersic_charly_ie(r_fit, ie[i-1] ,re[i-1],beta[i-1])/4.2545e10) 
       
        y_mue1 = sersic_charly_mue(r_fit,mue1[i-1] ,ree1[i-1],betaa1[i-1])
        y_ie_mu1 = mu(sersic_charly_ie(r_fit, ie1[i-1] ,re1[i-1],beta1[i-1])/4.2545e10)        
        
        ax.plot( r_091_reg[i][1:80],mu(i_091_reg[i][1:80]/4.2545e10),color='#FF8000',
                   label='mu-data',mfc='gray', mec='#FF8000', mew=3.2, marker='o',ms=10,alpha=0.7,linewidth='4')
        ax.plot(r_fit,y_mue, label='mu-fit',color='#CC6600',linestyle='-.')
        ax.plot(r_fit,y_ie_mu, label='ie-fit', color='#994C00', linestyle='--')        

        
        ax.plot( r_041_reg[i][1:80],mu(i_041_reg[i][1:80]/4.2545e10),color='#CC0066',
                   label='mu-data',mfc='gray', mec='#CC0066', mew=3.2, marker='o',ms=10,alpha=0.7,linewidth='4')
        ax.plot(r_fit,y_mue1, label='mu-fit', color='#99004C',linestyle='-.')
        ax.plot(r_fit,y_ie_mu1, label='ie-fit', color='#660033', linestyle='--')             
 
        pc  = plt.Rectangle((0,0), 0,0, color='white', alpha=0.3, label='dummy-tophead')
        l1  = plt.Line2D((0,1),(0,0), color='k', linestyle='-.')
        l2  = plt.Line2D((0,1),(0,0), color='k', linestyle='--')

    
        n=1./beta[i-1]
        nn=1./betaa[i-1]
        n1=1./beta1[i-1]
        nn1=1./betaa1[i-1]
    
        #ax.legend([p7,p1,p2,p3,p7,p4,p5,p6],labels, ncol=2) # Two columns, vertical group labels    
        w1='$\mu_{e}: $ '+str(round(mue[i-1],2))
        w2='$r_{e}: $ '+str(round(ree[i-1],2))
        w3='$n: $ '+str(round(nn,2))
        w4='$\mu_{e}: $ '+str(round(mu(ie[i-1]/4.2545e10),2))
        w5='$r_{e}: $ '+str(round(re[i-1],2))
        w6='$n: $ '+str(round(n,2))
        w7='$\mu_{e}: $ '+str(round(mue1[i-1],2))
        w8='$r_{e}: $ '+str(round(ree1[i-1],2))
        w9='$n: $ '+str(round(nn1,2))
        w10='$\mu_{e}: $ '+str(round(mu(ie1[i-1]/4.2545e10),2))
        w11='$r_{e}: $ '+str(round(re1[i-1],2))
        w12='$n: $ '+str(round(n1,2))
        w13='$R_{\mu_{24}}: $ '+str(round(rmu24_091[i-1],2))
        w14='$R_{\mu_{24}}: $ '+str(round(rmu24_041[i-1],2))
    
 
        legend_properties = {'weight':'bold'}

    
        objects=[pc,pc,pc,l1,pc,pc,pc,l2,pc,pc,pc,
             pc,pc,pc,pc,pc,pc,pc,pc,pc,pc,pc,
             pc,pc,pc,pc,pc,pc,pc,pc,pc,pc,pc]    
    
    
        labels= ['','','','$\mu$-fit','','','','$I_{e}$-fit','','','',
             'z=0','',w1,w2,w3,'',w4,w5,w6,'',w13,
             'z=1','',w7,w8,w9,'',w10,w11,w12,'',w14]
        l=plt.legend(objects, labels , loc='upper right', frameon=False,ncol=3,scatterpoints=1,borderpad=0.2, 
               labelspacing=0,columnspacing=-1,handlelength=2,handletextpad=0,borderaxespad=0.2)

        l.get_texts()[11].set_color('#994C00')
        l.get_texts()[13].set_color('#994C00')
        l.get_texts()[14].set_color('#994C00')
        l.get_texts()[15].set_color('#994C00')
        l.get_texts()[17].set_color('#994C00')
        l.get_texts()[18].set_color('#994C00')
        l.get_texts()[19].set_color('#994C00')    
        l.get_texts()[21].set_color('#994C00')
    
        l.get_texts()[22].set_color('#660033')
        l.get_texts()[24].set_color('#660033')
        l.get_texts()[25].set_color('#660033')
        l.get_texts()[26].set_color('#660033')
        l.get_texts()[28].set_color('#660033')
        l.get_texts()[29].set_color('#660033')
        l.get_texts()[30].set_color('#660033')
        l.get_texts()[32].set_color('#660033')      
        
        ax.set_ylim(25,20)
        ax.set_xlim(0,130)
        ax.set_title('D'+str(i))
        
        xticks = ax.xaxis.get_major_ticks()
        xticks[0].label1.set_visible(False)
        xticks[-1].label1.set_visible(False)
        yticks = ax.yaxis.get_major_ticks()
        yticks[0].label1.set_visible(False)
        #yticks[6].label1.set_visible(False)
        yticks[-1].label1.set_visible(False)
        
        ax.set_ylabel('$\mu_{e}$ [$mag/arcsec^{2}$]')
        ax.set_xlabel('R [Kpc]')
        
        ax.minorticks_on()
        #p1.title('D'+str(i))
        i=i+1
        
plt.savefig('/home/meugenia/Plantillas/ajustes_mues.pdf', format='pdf', dpi=1500,bbox_inches='tight') 
plt.show()

# %%
#perfiles en mu para cada region
r_fit=np.linspace(0,150,100)
for i in range(30):
    if i==30 or i==0:
        continue
    fig = plt.figure(figsize=(7,7))
    ax = fig.add_subplot(111)   
    
    y_mue = sersic_charly_mue(r_fit,mue[i-1] ,ree[i-1],betaa[i-1])
    y_ie_mu = mu(sersic_charly_ie(r_fit, ie[i-1] ,re[i-1],beta[i-1])/4.2545e10) 
       
    y_mue1 = sersic_charly_mue(r_fit,mue1[i-1] ,ree1[i-1],betaa1[i-1])
    y_ie_mu1 = mu(sersic_charly_ie(r_fit, ie1[i-1] ,re1[i-1],beta1[i-1])/4.2545e10)        
        
    p1=plt.plot( r_091_reg[i][1:80],mu(i_091_reg[i][1:80]/4.2545e10),color='#FF8000',
                   label='mu-data',mfc='gray', mec='#FF8000', mew=3.2, marker='o',ms=10,alpha=0.7,linewidth='4')
    p2=plt.plot(r_fit,y_mue, label='mu-fit',color='#CC6600',linestyle='-.')
    p3=plt.plot(r_fit,y_ie_mu, label='ie-fit', color='#994C00', linestyle='--')        
        
    p4=plt.plot( r_041_reg[i][1:80],mu(i_041_reg[i][1:80]/4.2545e10),color='#CC0066',
                   label='mu-data',mfc='gray', mec='#CC0066', mew=3.2, marker='o',ms=10,alpha=0.7,linewidth='4')
    p5=plt.plot(r_fit,y_mue1, label='mu-fit', color='#99004C',linestyle='-.')
    p6=plt.plot(r_fit,y_ie_mu1, label='ie-fit', color='#660033', linestyle='--')         

    pc  = plt.Rectangle((0,0), 0,0, color='white', alpha=0.3, label='dummy-tophead')
    l1  = plt.Line2D((0,1),(0,0), color='k', linestyle='-.')
    l2  = plt.Line2D((0,1),(0,0), color='k', linestyle='--')

    
    n=1./beta[0]
    nn=1./betaa[0]
    n1=1./beta1[0]
    nn1=1./betaa1[0]
    
    #ax.legend([p7,p1,p2,p3,p7,p4,p5,p6],labels, ncol=2) # Two columns, vertical group labels    
    w1='$\mu_{e}: $ '+str(round(mue[0],2))
    w2='$r_{e}: $ '+str(round(ree[0],2))
    w3='$n: $ '+str(round(nn,2))
    w4='$\mu_{e}: $ '+str(round(mu(ie[0]/4.2545e10),2))
    w5='$r_{e}: $ '+str(round(re[0],2))
    w6='$n: $ '+str(round(n,2))
    w7='$\mu_{e}: $ '+str(round(mue1[0],2))
    w8='$r_{e}: $ '+str(round(ree1[0],2))
    w9='$n: $ '+str(round(nn1,2))
    w10='$\mu_{e}: $ '+str(round(mu(ie1[0]/4.2545e10),2))
    w11='$r_{e}: $ '+str(round(re1[0],2))
    w12='$n: $ '+str(round(n1,2))
    w13='$R_{\mu_{24}}: $ '+str(round(rmu24_091[0],2))
    w14='$R_{\mu_{24}}: $ '+str(round(rmu24_041[0],2))
    
    objects=[pc,pc,pc,l1,pc,pc,pc,l2,pc,pc,pc,
             pc,pc,pc,pc,pc,pc,pc,pc,pc,pc,pc,
             pc,pc,pc,pc,pc,pc,pc,pc,pc,pc,pc]    
    
    
    labels= ['','','','$\mu$-fit','','','','$I_{e}$-fit','','','',
             'z=0','',w1,w2,w3,'',w4,w5,w6,'',w13,
             'z=1','',w7,w8,w9,'',w10,w11,w12,'',w14]
    l=plt.legend(objects, labels , loc='upper right', frameon=False,ncol=3,scatterpoints=1,borderpad=0.2, 
               labelspacing=0,columnspacing=-1,handlelength=2,handletextpad=0,borderaxespad=0.2)

    l.get_texts()[11].set_color('#994C00')
    l.get_texts()[13].set_color('#994C00')
    l.get_texts()[14].set_color('#994C00')
    l.get_texts()[15].set_color('#994C00')
    l.get_texts()[17].set_color('#994C00')
    l.get_texts()[18].set_color('#994C00')
    l.get_texts()[19].set_color('#994C00')    
    l.get_texts()[21].set_color('#994C00')
    
    l.get_texts()[22].set_color('#660033')
    l.get_texts()[24].set_color('#660033')
    l.get_texts()[25].set_color('#660033')
    l.get_texts()[26].set_color('#660033')
    l.get_texts()[28].set_color('#660033')
    l.get_texts()[29].set_color('#660033')
    l.get_texts()[30].set_color('#660033')
    l.get_texts()[32].set_color('#660033')
    #ax.legend(loc='upper right', frameon=False, scatterpoints=1,borderpad=0.1, labelspacing=0)
    ax.set_ylim(25,19)
    ax.set_xlim(0,130)
    ax.set_title('D'+str(i))
    
    ax.set_ylabel('$\mu_{e}$ [$mag/arcsec^{2}$]')
    ax.set_xlabel('R [Kpc]')    
    
    xticks = ax.xaxis.get_major_ticks()
    xticks[0].label1.set_visible(False)
    xticks[-1].label1.set_visible(False)
    yticks = ax.yaxis.get_major_ticks()
    yticks[0].label1.set_visible(False)
    #yticks[6].label1.set_visible(False)
    yticks[-1].label1.set_visible(False)
    ax.minorticks_on()
    #p1.title('D'+str(i))
    plt.savefig('plots2/ajustes_mues_D'+str(i)+'.pdf', format='pdf', dpi=1500,bbox_inches='tight') 
    plt.show()

# %%
#agrego ajuste pasando la salida del ajuste en mu a ie

ie____  = 4.2545e10*10**(-(mue[0]  + 48.6+0.044)/2.5)

index = next(x[0] for x in enumerate(r_091_reg[i]) if x[1] > rmu24_091[i-1])
xdata = r_091_reg[1][1:index+1]
ydata = i_091_reg[1][1:index+1]
p=[ie____, ree[0],betaa[0]]
popt, pcov = curve_fit(sersic_charly_ie, xdata, ydata,p)


y_sersic_mu  = sersic_charly_ie(r_fit,ie____,ree[0],betaa[0])
y_ie = sersic_charly_ie(r_fit, ie[0] ,re[0],beta[0])
y_ie2 = sersic_charly_ie(r_fit, popt[0] ,popt[1],popt[2])


plt.figure(figsize=(9,10))
plt.title('D'+str(1)) 
plt.plot( r_091_reg[1][1:70],i_091_reg[1][1:70],color='#FF8000',
        label='ie-data-z0',mfc='gray', mec='#FF8000', mew=3.2, marker='o',ms=10,alpha=0.7,linewidth='4')
plt.plot(r_fit,y_sersic_mu, label='mu-fit-z0', color='#CC6600',linestyle='-.')
plt.plot(r_fit,y_ie, label='ie-fit-z0', color='#994C00', linestyle='--')
plt.plot(r_fit,y_ie2, label='ie-fit-z0', color='green', linestyle='--')

plt.xlim(0,120)
plt.ylim(-0.1e-16,0.4e-16)
plt.ylim(-0.10e-17,1e-17)
plt.savefig('lalaD'+str(1)+'.pdf', format='pdf', dpi=1500,bbox_inches='tight') 

plt.show()

# %%
popt
# Out:
# array([  2.05627895e-18,   3.81809880e+01,   1.23671520e+00])

# %%
[ie____, ree[0], betaa[0]]
# Out:
# [3.1452018901759188e-19, 150.09999999999999, 0.28300999999999998]

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0,0.5)
y = x*(1.0-x)

a=3.1452018901759188e-19
w= "$I_{e}:$ "+"${0:0.2e}$".format(a)

plt.figure()
plt.plot(x, y)
plt.text(0.01, 0.23, w, size=20)
plt.show()

# %%
import scipy

# %%
scipy.special.gamma(2*0.51323)
# Out:
# 0.9854030001987294

# %%
index=0
index = next(x[0] for x in enumerate(r_041_reg[2]) if x[1] > rmu24_041[1])

# %%
#print index
print r_041_reg[1][index], rmu24_041[1]
# Out:
# 86.03 85.54

# %%
r_041_reg[1][index-1]
# Out:
# 82.030000000000001

# %%
r_041_reg[2]
# Out:
# array([   2.001,    6.002,   10.   ,   14.   ,   18.01 ,   22.01 ,
#          26.01 ,   30.01 ,   34.01 ,   38.01 ,   42.01 ,   46.01 ,
#          50.02 ,   54.02 ,   58.02 ,   62.02 ,   66.02 ,   70.02 ,
#          74.02 ,   78.02 ,   82.03 ,   86.03 ,   90.03 ,   94.03 ,
#          98.03 ,  102.   ,  106.   ,  110.   ,  114.   ,  118.   ,
#         122.   ,  126.   ,  130.   ,  134.   ,  138.   ,  142.   ,
#         146.   ,  150.   ,  154.   ,  158.   ,  162.1  ,  166.1  ,
#         170.1  ,  174.1  ,  178.1  ,  182.1  ,  186.1  ,  190.1  ,
#         194.1  ,  198.1  ,  202.1  ,  206.1  ,  210.1  ,  214.1  ,
#         218.1  ,  222.1  ,  226.1  ,  230.1  ,  234.1  ,  238.1  ,
#         242.1  ,  246.1  ,  250.1  ,  254.1  ,  258.1  ,  262.1  ,
#         266.1  ,  270.1  ,  274.1  ,  278.1  ,  282.1  ,  286.1  ,
#         290.1  ,  294.1  ,  298.1  ,  302.1  ,  306.1  ,  310.1  ,
#         314.1  ,  318.1  ])

# %%
x1 = r_041_reg[29][1:index+7]
y1 = m_091_reg[29][1:index+7]
x2 = r_041_reg[17][1:index+7]
y2 = m_091_reg[17][1:index+7]
x3 = r_041_reg[19][1:index+7]
y3 = m_091_reg[19][1:index+7]
x4 = r_041_reg[20][1:index+7]
y4 = m_091_reg[20][1:index+7]

# %%
plt.plot(x1,y1,color='blue')
plt.plot(x2,y2,color='red')
plt.plot(x3,y3,color='green')
plt.plot(x4,y4,color='orange')
plt.show()
